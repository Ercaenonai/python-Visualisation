# %%
import matplotlib.pyplot as plt
import numpy as np

def scatterplot(500, 1000, x_label="hours", y_label="wages", title="Hours_wages", color = "r", yscale_log=False):

    # Create the plot object
    _, ax = plt.subplots()

    # Plot the data, set the size (s), color and transparency (alpha)
    # of the points
    ax.scatter(x_data, y_data, s = 10, color = color, alpha = 0.75)

    if yscale_log == True:
        ax.set_yscale('log')

    # Label the axes and provide a title
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
plt.plot(x, y,)
# Out:
#   File "<ipython-input-3-04156ddb4664>", line 4
#     def scatterplot(500, 1000, x_label="hours", y_label="wages", title="Hours_wages", color = "r", yscale_log=False):
#                       ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

def scatterplot(x_data, y_data, x_label="", y_label="", title="", color = "r", yscale_log=False):

    # Create the plot object
    _, ax = plt.subplots()

    # Plot the data, set the size (s), color and transparency (alpha)
    # of the points
    ax.scatter(x_data, y_data, s = 10, color = color, alpha = 0.75)

    if yscale_log == True:
        ax.set_yscale('log')

    # Label the axes and provide a title
    ax.set_title(title)
    ax.set_xlabel(hour)
    ax.set_ylabel(wages)
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fa6ffa98ff59> in <module>
#      18     ax.set_xlabel(hour)
#      19     ax.set_ylabel(wages)
# ---> 20 plot.show()
#
# NameError: name 'plot' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

def scatterplot(x_data, y_data, x_label="hours", y_label="wages", title="Hours vs. Wages", color = "b", yscale_log=False):

    # Create the plot object
    _, ax = plt.subplots()

    # Plot the data, set the size (s), color and transparency (alpha)
    # of the points
    ax.scatter(x_data, y_data, s = 10, color = color, alpha = 0.75)

    if yscale_log == True:
        ax.set_yscale('log')

    # Label the axes and provide a title
    ax.set_title(hours_wages)
    ax.set_xlabel(hours)
    ax.set_ylabel(wages)
plt.plot()
# Out:
# []

# %%
from bokeh.plotting import figure, output_file, show
 
# 1. Load some data in X,Y variables
x = [1, 2, 3, 4, 5]
y = [23, 15, 7, 12, 21]
 
# 2. Specify the name of the output HTML file
output_file(“lines.html”)
 
#3. create a new plot with a title and axis labels
p = figure(title=”Bokeh Demo for OSFY”, x_axis_label=’x’, y_axis_label=’y’)
 
#4. add a line renderer with legend and line thickness
p.line(x, y, legend=”Age”, line_width=3)
 
#5. show the results
show(p)
# Out:
#   File "<ipython-input-16-217f394e5b11>", line 8
#     output_file(“lines.html”)
#                      ^
# SyntaxError: invalid character in identifier

# %%
import numpy as np
from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_file, show
# prepare some data
N = 100
x = np.linspace(0, 4*np.pi, N)
y0 = np.sin(x)
y1 = np.cos(x)
y2 = np.sin(x) + np.cos(x)
# output to static HTML file
output_file(“linked_panning.html”)
# create a new plot
s1 = figure(width=250, plot_height=250, title=None)
s1.circle(x, y0, size=10, color=”blue”, alpha=0.5)
# NEW: create a new plot and share both ranges
s2 = figure(width=250, height=250, x_range=s1.x_range, y_range=s1.y_range, title=None)
s2.triangle(x, y1, size=10, color=”firebrick”, alpha=0.5)
# NEW: create a new plot and share only one range
s3 = figure(width=250, height=250, x_range=s1.x_range, title=None)
s3.square(x, y2, size=10, color=”green”, alpha=0.5)
# NEW: put the subplots in a gridplot
p = gridplot([[s1, s2, s3]], toolbar_location=None)
# show the results
show(p)
# Out:
#   File "<ipython-input-17-01ec44b7754b>", line 11
#     output_file(“linked_panning.html”)
#                               ^
# SyntaxError: invalid character in identifier

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.plot([1,2,3,4,5], [1,5,6,12,20])
plt.title('Test Plot', fontsize=30, color='g')
plt.xlabel('Python Mountain', fontsize=20, color='r')
plt.ylabel('A Slow Ascent', fontsize=15, color='b')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(2,5))
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0,6,0,20])
plt.annotate('You Should Hire ME!!!', (6,6), fontsize=20, color='r')
plt.show()

# %%
import sys
from termcolor import colored, cprint

text = colored('Hello, World!', 'red', attrs=['reverse', 'blink'])
print(text)
cprint('Hello, World!', 'green', 'on_red')

print_red_on_cyan = lambda x: cprint(x, 'red', 'on_cyan')
print_red_on_cyan('Hello, World!')
print_red_on_cyan('Hello, Universe!')

for i in range(10):
    cprint(i, 'magenta', end=' ')

cprint("Attention!", 'red', attrs=['bold'], file=sys.stderr)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-bfe91a8e65aa> in <module>
#       1 import sys
# ----> 2 from termcolor import colored, cprint
#       3
#       4 text = colored('Hello, World!', 'red', attrs=['reverse', 'blink'])
#       5 print(text)
#
# ModuleNotFoundError: No module named 'termcolor'

# %%
plt.clf() #   Clears elements off figures
x = np.arange(4)
y = [8.8, 5.2, 3.6, 5.9]
plt.xticks(x, ('Hire', 'Me', 'Please???', 'Thank you'), fontsize=15, color='b')
plt.bar(x,y, color=['lime', 'r', 'k','tan'])
plt.show()

# %%
d= {'Hire' : np.random.rand(10), 'ME' : np.random.rand(10)}
df = pd.DataFrame(d)
df.plot(style=['ro', 'gx'])
plt.show()

# %%
ts = pd.Series(np.random.randn(180), index=pd.date_range('1/1/2018', periods=180))
df = pd.DataFrame(np.random.randn(180,3), index=ts.index, columns=list('ABC'))
df.cumsum().plot()
plt.show()

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sizes = (30 * np.random.rand(N))**2
plt.scatter(x, y, s=sizes, c=colors, alpha=0.5)
plt.show()

# %%
df = pd.read_csv('CSV NAME.txt')

# %%
fig, plots = plt.subplots(2, sharex=True)
fig.suptitle('Share X')
x = range(0,200,5)
y = [n**0.8 for n in x]
plots[0].plot(x,y, color='r')
plots[1]. scatter(x, y)
plt.show()
